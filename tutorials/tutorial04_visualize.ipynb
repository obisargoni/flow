# %% [markdown]
# # Tutorial 04: Visualizing Experiment Results

# %% [markdown]
# This tutorial describes the process of visualizing the results of Flow experiments, and of replaying them.
#
# **Note:** This tutorial is only relevant if you use SUMO as a simulator. We currently do not support policy replay nor data collection when using Aimsun. The only exception is for reward plotting, which is independent on whether you have used SUMO or Aimsun during training.

# %% [markdown]
# ## 1. Visualization components

# %% [markdown]
# The visualization of simulation results breaks down into three main components:
#
# - **reward plotting**: Visualization of the reward function is an essential step in evaluating the effectiveness and training progress of RL agents.
#
# - **policy replay**: Flow includes tools for visualizing trained policies using SUMO's GUI. This enables more granular analysis of policies beyond their accrued reward, which in turn allows users to tweak actions, observations and rewards in order to produce some desired behavior. The visualizers also generate plots of observations and a plot of the reward function over the course of the rollout.
#
# - **data collection and analysis**: Any Flow experiment can output its simulation data to a CSV file, `emission.csv`, containing the contents of SUMO's built-in `emission.xml` files. This file contains various data such as the speed, position, time, fuel consumption and many other metrics for every vehicle in the network and at each time step of the simulation. Once you have generated the `emission.csv` file, you can open it and read the data it contains using Python's [csv library](https://docs.python.org/3/library/csv.html) (or using Excel).

# %% [markdown]
# Visualization is different depending on which reinforcement learning library you are using, if any. Accordingly, the rest of this tutorial explains how to plot rewards, replay policies and collect data when using either no RL library, RLlib, or stable-baselines.

# %% [markdown]
# **Contents:**
#
# [How to visualize using SUMO without training](#2.1---Using-SUMO-without-training)
#
# [How to visualize using SUMO with RLlib](#2.2---Using-SUMO-with-RLlib)
#
# [**_Example: visualize data on a ring trained using RLlib_**](#2.3---Example:-Visualize-data-on-a-ring-trained-using-RLlib)

# %% [markdown]
# ## 2. How to visualize

# %% [markdown]
# ### 2.1 - Using SUMO without training
#
# _In this case, since there is no training, there is no reward to plot and no policy to replay._

# %% [markdown]
# #### Data collection and analysis
#
# SUMO-only experiments can generate emission CSV files seamlessly:
#
# First, you have to tell SUMO to generate the `emission.xml` files. You can do that by specifying `emission_path` in the simulation parameters (class `SumoParams`), which is the path where the emission files will be generated. For instance:

# %%
from flow.core.params import SumoParams

sim_params = SumoParams(sim_step=0.1, render=True, emission_path='data')

# %% [markdown]
# Then, you have to tell Flow to convert these XML emission files into CSV files. To do that, pass in `convert_to_csv=True` to the `run` method of your experiment object. For instance:
#
# ```python
# exp.run(1, convert_to_csv=True)
# ```

# %% [markdown]
# When running experiments, Flow will now automatically create CSV files next to the SUMO-generated XML files.

# %% [markdown]
# ### 2.2 - Using SUMO with RLlib

# %% [markdown]
# #### Reward plotting
#
# RLlib supports reward visualization over the period of the training using the `tensorboard` command. It takes one command-line parameter, `--logdir`, which is an RLlib result directory. By default, it would be located within an experiment directory inside your `~/ray_results` directory.
#
# An example call would look like:
#
# `tensorboard --logdir ~/ray_results/experiment_dir/result/directory`
#
# You can also run `tensorboard --logdir ~/ray_results` if you want to select more than just one experiment.
#
# If you do not wish to use `tensorboard`, an other way is to use our `flow/visualize/plot_ray_results.py` tool. It takes as arguments:
#
# - the path to the `progress.csv` file located inside your experiment results directory (`~/ray_results/...`),
# - the name(s) of the column(s) you wish to plot (reward or other things).
#
# An example call would look like:
#
# `flow/visualize/plot_ray_results.py ~/ray_results/experiment_dir/result/progress.csv training/return-average training/return-min`
#
# If you do not know what the names of the columns are, run the command without specifying any column:
#
# `flow/visualize/plot_ray_results.py ~/ray_results/experiment_dir/result/progress.csv`
#
# and the list of all available columns will be displayed to you.

# %%
# Visualise results from training example
# !python ../flow/visualize/plot_ray_results.py ~/ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_a44c242e_2021-01-20_18-23-49kmm2_suf"/progress.csv
# Out:
# Columns are: episode_reward_max, episode_reward_min, episode_reward_mean, episode_len_mean, episodes_this_iter, timesteps_this_iter, done, timesteps_total, episodes_total, training_iteration, experiment_id, date, timestamp, time_this_iter_s, time_total_s, pid, hostname, node_ip, time_since_restore, timesteps_since_restore, iterations_since_restore, num_healthy_workers, trial_id, experiment_tag, sampler_perf/mean_env_wait_ms, sampler_perf/mean_processing_ms, sampler_perf/mean_inference_ms, info/num_steps_trained, info/num_steps_sampled, info/sample_time_ms, info/load_time_ms, info/grad_time_ms, info/update_time_ms, perf/cpu_util_percent, perf/ram_util_percent, info/learner/default_policy/cur_kl_coeff, info/learner/default_policy/cur_lr, info/learner/default_policy/total_loss, info/learner/default_policy/policy_loss, info/learner/default_policy/vf_loss, info/learner/default_policy/vf_explained_var, info/learner/default_policy/kl, info/learner/default_policy/entropy, info/learner/default_policy/entropy_coeff

# %%
# does not plot any data which suggests that the training example isn't working
# !python ../flow/visualize/plot_ray_results.py ~/ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_a44c242e_2021-01-20_18-23-49kmm2_suf"/progress.csv episode_reward_max episode_reward_min
# Out:
# Figure(640x480)

# %% [markdown]
# #### Policy replay
#
# The tool to replay a policy trained using RLlib is located at `flow/visualize/visualizer_rllib.py`. It takes as argument, first the path to the experiment results (by default located within `~/ray_results`), and secondly the number of the checkpoint you wish to visualize (which correspond to the folder `checkpoint_<number>` inside the experiment results directory).
#
# An example call would look like this:
#
# `python flow/visualize/visualizer_rllib.py ~/ray_results/experiment_dir/result/directory 1`
#
# There are other optional parameters which you can learn about by running `visualizer_rllib.py --help`.

# %% [markdown]
# #### Data collection and analysis
#
# Simulation data can be generated the same way as it is done [without training](#2.1---Using-SUMO-without-training).
#
# If you need to generate simulation data after the training, you can run a policy replay as mentioned above, and add the `--gen-emission` parameter.
#
# An example call would look like:
#
# `python flow/visualize/visualizer_rllib.py ~/ray_results/experiment_dir/result/directory 1 --gen_emission`

# %% [markdown]
# ### 2.3 - Example: Visualize data on a ring trained using RLlib

# %%
# !pwd  # make sure you are in the flow/tutorials folder
# Out:
# /home/obisargoni/flow/tutorials

# %% [markdown]
# The folder `flow/tutorials/data/trained_ring` contains the data generated in `ray_results` after training an agent on a ring scenario for 200 iterations using RLlib (the experiment can be found in `flow/examples/rllib/stabilizing_the_ring.py`).
#
# Let's first have a look at what's available in the `progress.csv` file:

# %%
# !python ../flow/visualize/plot_ray_results.py data/trained_ring/progress.csv
# Out:
# Columns are: episode_reward_max, episode_reward_min, episode_reward_mean, episode_len_mean, episodes_this_iter, timesteps_this_iter, done, timesteps_total, episodes_total, training_iteration, experiment_id, date, timestamp, time_this_iter_s, time_total_s, pid, hostname, node_ip, time_since_restore, timesteps_since_restore, iterations_since_restore, num_healthy_workers, trial_id, sampler_perf/mean_env_wait_ms, sampler_perf/mean_processing_ms, sampler_perf/mean_inference_ms, info/num_steps_trained, info/num_steps_sampled, info/sample_time_ms, info/load_time_ms, info/grad_time_ms, info/update_time_ms, perf/cpu_util_percent, perf/ram_util_percent, info/learner/default_policy/cur_kl_coeff, info/learner/default_policy/cur_lr, info/learner/default_policy/total_loss, info/learner/default_policy/policy_loss, info/learner/default_policy/vf_loss, info/learner/default_policy/vf_explained_var, info/learner/default_policy/kl, info/learner/default_policy/entropy, info/learner/default_policy/entropy_coeff

# %% [markdown]
# This gives us a list of everything that we can plot. Let's plot the reward and its boundaries:

# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run ../flow/visualize/plot_ray_results.py data/trained_ring/progress.csv \
episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# We can see that the policy had already converged by the iteration 50.
#
# Now let's see what this policy looks like. Run the following script, then click on the green arrow to run the simulation (you may have to click several times).

# %%
# !python ../flow/visualize/visualizer_rllib.py data/trained_ring 20 --horizon 2000
# Out:
# 2021-01-20 17:35:15,442	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2021-01-20 17:35:15,444	INFO resource_spec.py:216 -- Starting Ray with 2.25 GiB memory available for workers and up to 1.14 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2021-01-20 17:35:16,303	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2021-01-20 17:35:18,773	INFO rollout_worker.py:770 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f0cc3289860>}
# 2021-01-20 17:35:18,774	INFO rollout_worker.py:771 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f0cc32895f8>}
# 2021-01-20 17:35:18,774	INFO rollout_worker.py:372 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f0cc3289470>}
# 2021-01-20 17:35:18,778	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2021-01-20 17:35:21,286	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# Traceback (most recent call last):
#   File "../flow/visualize/visualizer_rllib.py", line 386, in <module>
#     visualizer_rllib(args)
#   File "../flow/visualize/visualizer_rllib.py", line 155, in visualizer_rllib
#     agent.restore(checkpoint)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/tune/trainable.py", line 341, in restore
#     self._restore(checkpoint_path)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 559, in _restore
#     self.__setstate__(extra_data)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 161, in __setstate__
#     Trainer.__setstate__(self, state)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 855, in __setstate__
#     self.workers.local_worker().restore(state["worker"])
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 712, in restore
#     self.policy_map[pid].set_state(state)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/policy.py", line 250, in set_state
#     self.set_weights(state)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py", line 269, in set_weights
#     return self._variables.set_weights(weights)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/experimental/tf_utils.py", line 186, in set_weights
#     self.assignment_nodes[name] for name in new_weights.keys()
# AttributeError: 'numpy.ndarray' object has no attribute 'keys'

# %% [markdown]
# The RL agent is properly stabilizing the ring!
#
# Indeed, without an RL agent, the vehicles start forming stop-and-go waves which significantly slows down the traffic, as you can see in this simulation:

# %%
# !python ../examples/simulate.py ring
# Out:
# Round 0, return: 424.1221323836512
# Average, std returns: 424.1221323836512, 0.0
# Average, std velocities: 2.883939027587335, 0.0
# Average, std outflows: 0.0, 0.0
# Total time: 18.151270389556885
# steps/second: 95.97376451422389

# %% [markdown]
# In the trained ring folder, there is a checkpoint generated every 20 iterations. Try to run the second previous command but replace 200 by 20. On the reward plot, you can see that the reward is already quite high at iteration 20, but hasn't converged yet, so the agent will perform a little less well than at iteration 200.

# %% [markdown]
# That's it for this example! Feel free to play around with the other scripts in `flow/visualize`. Run them with the `--help` parameter and it should tell you how to use it. Also, if you need the emission file for the trained ring, you can obtain it by running the following command:

# %%
# !python ../flow/visualize/visualizer_rllib.py data/trained_ring 200 --horizon 2000 --gen_emission
# Out:
# 2021-01-20 17:25:08,884	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2021-01-20 17:25:08,885	INFO resource_spec.py:216 -- Starting Ray with 2.54 GiB memory available for workers and up to 1.28 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2021-01-20 17:25:09,241	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2021-01-20 17:25:11,611	INFO rollout_worker.py:770 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f3c7e0b0748>}
# 2021-01-20 17:25:11,611	INFO rollout_worker.py:771 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x7f3c7e0b04e0>}
# 2021-01-20 17:25:11,612	INFO rollout_worker.py:372 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f3c7e0b0390>}
# 2021-01-20 17:25:11,614	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2021-01-20 17:25:14,108	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# Traceback (most recent call last):
#   File "../flow/visualize/visualizer_rllib.py", line 386, in <module>
#     visualizer_rllib(args)
#   File "../flow/visualize/visualizer_rllib.py", line 155, in visualizer_rllib
#     agent.restore(checkpoint)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/tune/trainable.py", line 341, in restore
#     self._restore(checkpoint_path)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 559, in _restore
#     self.__setstate__(extra_data)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py", line 161, in __setstate__
#     Trainer.__setstate__(self, state)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/agents/trainer.py", line 855, in __setstate__
#     self.workers.local_worker().restore(state["worker"])
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/evaluation/rollout_worker.py", line 712, in restore
#     self.policy_map[pid].set_state(state)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/policy.py", line 250, in set_state
#     self.set_weights(state)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py", line 269, in set_weights
#     return self._variables.set_weights(weights)
#   File "/home/obisargoni/miniconda3/envs/flow/lib/python3.7/site-packages/ray/experimental/tf_utils.py", line 186, in set_weights
#     self.assignment_nodes[name] for name in new_weights.keys()
# AttributeError: 'numpy.ndarray' object has no attribute 'keys'

# %% [markdown]
# The path where the emission file is generated will be outputted at the end of the simulation.

# %%
# !python ../flow/visualize/visualizer_rllib.py ../ray_results/training_example_20210120/PPO_WaveAttenuationPOEnv-v0_db2ecdb4_2021-01-20_17-28-05muufaqy9 1 --horizon 200
# Out:
# 2021-01-20 17:36:12,576	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2021-01-20 17:36:12,580	INFO resource_spec.py:216 -- Starting Ray with 2.25 GiB memory available for workers and up to 1.14 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# Traceback (most recent call last):
#   File "../flow/visualize/visualizer_rllib.py", line 386, in <module>
#     visualizer_rllib(args)
#   File "../flow/visualize/visualizer_rllib.py", line 56, in visualizer_rllib
#     config = get_rllib_config(result_dir)
#   File "/home/obisargoni/flow/flow/utils/rllib.py", line 202, in get_rllib_config
#     "Could not find params.json in either the checkpoint dir or "
# ValueError: Could not find params.json in either the checkpoint dir or its parent directory.

# %% [markdown]
# ### Visualising results of training run through rllib tutorial

# %% [markdown]
# Results from this tutorial are saved in these locations
#
# ../ray_results/training_example_20210120/PPO_WaveAttenuationPOEnv-v0_db2ecdb4_2021-01-20_17-28-05muufaqy9
#
# ../ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_2fec08b6_2021-01-20_18-13-24qi8aj_vl

# %%
# !python ../flow/visualize/plot_ray_results.py ../../ray_results/training_example/"PPO_WaveAttenuationPOEnv-v0_2fec08b6_2021-01-20_18-13-24qi8aj_vl"/progress.csv
# Out:
# Columns are: episode_reward_max, episode_reward_min, episode_reward_mean, episode_len_mean, episodes_this_iter, timesteps_this_iter, done, timesteps_total, episodes_total, training_iteration, experiment_id, date, timestamp, time_this_iter_s, time_total_s, pid, hostname, node_ip, time_since_restore, timesteps_since_restore, iterations_since_restore, num_healthy_workers, trial_id, experiment_tag, sampler_perf/mean_env_wait_ms, sampler_perf/mean_processing_ms, sampler_perf/mean_inference_ms, info/num_steps_trained, info/num_steps_sampled, info/sample_time_ms, info/load_time_ms, info/grad_time_ms, info/update_time_ms, perf/cpu_util_percent, perf/ram_util_percent, info/learner/default_policy/cur_kl_coeff, info/learner/default_policy/cur_lr, info/learner/default_policy/total_loss, info/learner/default_policy/policy_loss, info/learner/default_policy/vf_loss, info/learner/default_policy/vf_explained_var, info/learner/default_policy/kl, info/learner/default_policy/entropy, info/learner/default_policy/entropy_coeff

# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run ../flow/visualize/plot_ray_results.py ../../ray_results/training_example2/"PPO_WaveAttenuationPOEnv-v0_2391c0dc_2021-01-22_10-54-023kyhhwvj"/progress.csv \
episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ### Visualising results of examples/train.py script with nsteps = 100
#
# Horizon and nrollouts fixed at 3000 and 20 by train.py script
#
# Results here:
#
# ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r"/

# %%
# !python ../flow/visualize/plot_ray_results.py ../../ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r"/progress.csv
# Out:
# Columns are: episode_reward_max, episode_reward_min, episode_reward_mean, episode_len_mean, episodes_this_iter, timesteps_this_iter, done, timesteps_total, episodes_total, training_iteration, experiment_id, date, timestamp, time_this_iter_s, time_total_s, pid, hostname, node_ip, time_since_restore, timesteps_since_restore, iterations_since_restore, num_healthy_workers, trial_id, experiment_tag, sampler_perf/mean_env_wait_ms, sampler_perf/mean_processing_ms, sampler_perf/mean_inference_ms, info/num_steps_trained, info/num_steps_sampled, info/sample_time_ms, info/load_time_ms, info/grad_time_ms, info/update_time_ms, perf/cpu_util_percent, perf/ram_util_percent, info/learner/default_policy/cur_kl_coeff, info/learner/default_policy/cur_lr, info/learner/default_policy/total_loss, info/learner/default_policy/policy_loss, info/learner/default_policy/vf_loss, info/learner/default_policy/vf_explained_var, info/learner/default_policy/kl, info/learner/default_policy/entropy, info/learner/default_policy/entropy_coeff

# %% [markdown]
# Can view the results!

# %%
# %matplotlib notebook
# %run ../flow/visualize/plot_ray_results.py ../../ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r"/progress.csv \
episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# Now try run simulation from a check point

# %%
# !python ../flow/visualize/visualizer_rllib.py ../../ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r" 20 --horizon 3000
# Out:
# 2021-01-25 11:00:17,719	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2021-01-25 11:00:17,720	INFO resource_spec.py:216 -- Starting Ray with 2.54 GiB memory available for workers and up to 1.29 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2021-01-25 11:00:18,074	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2021-01-25 11:00:18,083	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2021-01-25 11:00:23,503	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2021-01-25 11:00:23,592	INFO trainable.py:346 -- Restored from checkpoint: ../../ray_results/stabilizing_the_ring/PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r/checkpoint_20/checkpoint-20
# 2021-01-25 11:00:23,593	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 20, '_timesteps_total': 1200000, '_time_total': 6472.3076248168945, '_episodes_total': 400}
#
# -----------------------
# ring length: 221
# v_max: 3.285334164169417
# -----------------------
# Round 0, Return: -1545.8064719005731
# ==== Summary of results ====
# Return:
# [2.5317252439637654]
# [-1545.8064719005731]
# Average, std: -1545.8064719005731, 0.0
#
# Speed, mean (m/s):
# [2.5317252439637654]
# Average, std: 2.5317252439637654, 0.0
#
# Speed, std (m/s):
# [0.554297207875622]
# Average, std: 0.554297207875622, 0.0
#
# Outflows (veh/hr):
# [0.0]
# Average, std: 0.0, 0.0
# Inflows (veh/hr):
# [0.0]
# Average, std: 0.0, 0.0
# Throughput efficiency (veh/hr):
# [0]
# Average, std: 0.0, 0.0

# %%
# !python ../flow/visualize/visualizer_rllib.py ../../ray_results/stabilizing_the_ring/"PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r" 40 --horizon 3000
# Out:
# 2021-01-25 11:01:41,241	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2021-01-25 11:01:41,241	INFO resource_spec.py:216 -- Starting Ray with 2.54 GiB memory available for workers and up to 1.27 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2021-01-25 11:01:41,608	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2021-01-25 11:01:41,624	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2021-01-25 11:01:46,368	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2021-01-25 11:01:46,453	INFO trainable.py:346 -- Restored from checkpoint: ../../ray_results/stabilizing_the_ring/PPO_WaveAttenuationPOEnv-v0_52cb8e02_2021-01-22_15-27-22k0w4_09r/checkpoint_40/checkpoint-40
# 2021-01-25 11:01:46,453	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 40, '_timesteps_total': 2400000, '_time_total': 13084.936424255371, '_episodes_total': 800}
#
# -----------------------
# ring length: 258
# v_max: 5.044800727535787
# -----------------------
# Round 0, Return: 2670.7186570197314
# ==== Summary of results ====
# Return:
# [4.690246892220526]
# [2670.7186570197314]
# Average, std: 2670.7186570197314, 0.0
#
# Speed, mean (m/s):
# [4.690246892220526]
# Average, std: 4.690246892220526, 0.0
#
# Speed, std (m/s):
# [0.03787026131816738]
# Average, std: 0.03787026131816738, 0.0
#
# Outflows (veh/hr):
# [0.0]
# Average, std: 0.0, 0.0
# Inflows (veh/hr):
# [0.0]
# Average, std: 0.0, 0.0
# Throughput efficiency (veh/hr):
# [0]
# Average, std: 0.0, 0.0
